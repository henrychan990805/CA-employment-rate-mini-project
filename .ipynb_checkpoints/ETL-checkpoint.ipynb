# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="f2d571a0-5c6e-424f-b311-3114cc932e2f" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"aaf555f9-b24e-44c3-9d60-fbdb08fd18b3":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"0e1aabffb4a346579f43a662d473cad8","client_comm_id":"1840d049ee4e4e689fcd3633ac492b2c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"aaf555f9-b24e-44c3-9d60-fbdb08fd18b3","roots":{"p1002":"f2d571a0-5c6e-424f-b311-3114cc932e2f"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
#Read in employment and unemployment datasets to pandas dataframe
employment_df = pd.read_csv('./Datasets/updated_employment_data.csv')
employment_df
# Out:
#         Unnamed: 0 Area Type       Area Name  Year    Month       Date  \
# 0                0    County  Alameda County  2014  January  01/1/2014
# 1                1    County  Alameda County  2014  January  01/1/2014
# 2                2    County  Alameda County  2014  January  01/1/2014
# 3                3    County  Alameda County  2014  January  01/1/2014
# 4                4    County  Alameda County  2014  January  01/1/2014
# ...            ...       ...             ...   ...      ...        ...
# 482099      482099     State      California  2024    March  03/1/2024
# 482100      482100     State      California  2024    March  03/1/2024
# 482101      482101     State      California  2024    March  03/1/2024
# 482102      482102     State      California  2024    March  03/1/2024
# 482103      482103     State      California  2024    March  03/1/2024
#
#                                            Industry Title  \
# 0                                           Manufacturing
# 1                                         Wholesale Trade
# 2               Transportation, Warehousing, and Utili...
# 3                                             Information
# 4                 Management of Companies and Enterprises
# ...                                                   ...
# 482099                               Truck Transportation
# 482100              Depository Credit Intermediation i...
# 482101                               Financial Activities
# 482102                  Wired Telecommunications Carriers
# 482103              Media Streaming Distribution Servi...
#
#         Industry Current Employment  Regional Labor Force  \
# 0                             65300                797300
# 1                             36700                797300
# 2                             24400                797300
# 3                             13900                797300
# 4                             18400                797300
# ...                             ...                   ...
# 482099                       148700              19409300
# 482100                       126700              19409300
# 482101                       801200              19409300
# 482102                        36600              19409300
# 482103                        65600              19409300
#
#         Regional Employment  Regional Unemployment  Regional Unemployment Rate
# 0                    744800                  52500                         6.6
# 1                    744800                  52500                         6.6
# 2                    744800                  52500                         6.6
# 3                    744800                  52500                         6.6
# 4                    744800                  52500                         6.6
# ...                     ...                    ...                         ...
# 482099             18372600                1036700                         5.3
# 482100             18372600                1036700                         5.3
# 482101             18372600                1036700                         5.3
# 482102             18372600                1036700                         5.3
# 482103             18372600                1036700                         5.3
#
# [482104 rows x 12 columns]

# %%
california_unemployment_df=employment_df.loc[employment_df['Area Name']=='California']
california_unemployment_df
# Out:
#         Unnamed: 0 Area Type   Area Name  Year    Month       Date  \
# 3690          3690     State  California  2014  January  01/1/2014
# 3691          3691     State  California  2014  January  01/1/2014
# 3692          3692     State  California  2014  January  01/1/2014
# 3693          3693     State  California  2014  January  01/1/2014
# 3694          3694     State  California  2014  January  01/1/2014
# ...            ...       ...         ...   ...      ...        ...
# 482099      482099     State  California  2024    March  03/1/2024
# 482100      482100     State  California  2024    March  03/1/2024
# 482101      482101     State  California  2024    March  03/1/2024
# 482102      482102     State  California  2024    March  03/1/2024
# 482103      482103     State  California  2024    March  03/1/2024
#
#                                            Industry Title  \
# 3690                Computer and Peripheral Equipment ...
# 3691             Bare Printed Circuit Board Manufacturing
# 3692               Transportation Equipment Manufacturing
# 3693              Computer and Electronic Product Manu...
# 3694                                          Real Estate
# ...                                                   ...
# 482099                               Truck Transportation
# 482100              Depository Credit Intermediation i...
# 482101                               Financial Activities
# 482102                  Wired Telecommunications Carriers
# 482103              Media Streaming Distribution Servi...
#
#         Industry Current Employment  Regional Labor Force  \
# 3690                          63600              18496400
# 3691                           8600              18496400
# 3692                         110800              18496400
# 3693                         263000              18496400
# 3694                         199800              18496400
# ...                             ...                   ...
# 482099                       148700              19409300
# 482100                       126700              19409300
# 482101                       801200              19409300
# 482102                        36600              19409300
# 482103                        65600              19409300
#
#         Regional Employment  Regional Unemployment  Regional Unemployment Rate
# 3690               16922600                1573700                         8.5
# 3691               16922600                1573700                         8.5
# 3692               16922600                1573700                         8.5
# 3693               16922600                1573700                         8.5
# 3694               16922600                1573700                         8.5
# ...                     ...                    ...                         ...
# 482099             18372600                1036700                         5.3
# 482100             18372600                1036700                         5.3
# 482101             18372600                1036700                         5.3
# 482102             18372600                1036700                         5.3
# 482103             18372600                1036700                         5.3
#
# [34679 rows x 12 columns]

# %%
 new_df=(california_unemployment_df.groupby(california_unemployment_df['Year'])[['Regional Employment','Regional Unemployment']]).mean()
new_df=new_df.reset_index()
new_df
# Out:
#     Year  Regional Employment  Regional Unemployment
# 0   2014         1.726452e+07           1.412175e+06
# 1   2015         1.764742e+07           1.176742e+06
# 2   2016         1.796541e+07           1.046617e+06
# 3   2017         1.825807e+07           9.273000e+05
# 4   2018         1.846990e+07           8.196000e+05
# 5   2019         1.858954e+07           7.957000e+05
# 6   2020         1.703703e+07           1.921575e+06
# 7   2021         1.756875e+07           1.387825e+06
# 8   2022         1.834892e+07           8.204167e+05
# 9   2023         1.838831e+07           9.200207e+05
# 10  2024         1.830787e+07           1.076267e+06

# %%
new_df.plot(x="Year", y=["Regional Employment", "Regional Unemployment"],kind="bar",stacked=True)
plt.title("Changes of employment and unemployment data in California from 2014 to 2024")

plt.gcf().axes[0].yaxis.get_major_formatter().set_scientific(False)

# %%
avg_df=(california_unemployment_df.groupby(california_unemployment_df['Year'])['Regional Unemployment Rate']).mean()
avg_df.plot.bar()
plt.ylabel("Average nemployment Rate")
plt.title("California unemploymentrate over years")

plt.show()

# %%
top10_emp_df=employment_df['Industry Title'].value_counts()
top10_emp_df.head(15)
# Out:
# Industry Title
# Government                                     10614
# Federal Government                             10614
# Local Government                               10614
# Total Nonfarm                                  10614
# State Government                               10614
# Total Farm                                     10614
#      Service-Providing                         10614
# Total Wage and Salary                          10614
# Goods Producing                                10614
#       Private Education and Health Services    10368
#       Leisure and Hospitality                  10368
#      Trade, Transportation, and Utilities      10368
# Manufacturing                                  10245
#       Financial Activities                     10122
# Retail Trade                                    9999
# Name: count, dtype: int64

# %%
title=['Total Nonfarm','Government','Federal Government','Local Government','State Government','Total Farm','Manufacturing','Goods Producing','Total Wage and Salary','Retail Trade']
top10_filter_emp_df=employment_df.loc[employment_df['Industry Title'].isin(title)]
top10_filter_emp_df
# Out:
#         Unnamed: 0 Area Type       Area Name  Year    Month       Date  \
# 0                0    County  Alameda County  2014  January  01/1/2014
# 7                7    County  Alameda County  2014  January  01/1/2014
# 10              10    County  Alameda County  2014  January  01/1/2014
# 14              14    County  Alameda County  2014  January  01/1/2014
# 15              15    County  Alameda County  2014  January  01/1/2014
# ...            ...       ...             ...   ...      ...        ...
# 481958      481958     State      California  2024    March  03/1/2024
# 481978      481978     State      California  2024    March  03/1/2024
# 481998      481998     State      California  2024    March  03/1/2024
# 482005      482005     State      California  2024    March  03/1/2024
# 482056      482056     State      California  2024    March  03/1/2024
#
#                Industry Title  Industry Current Employment  \
# 0               Manufacturing                        65300
# 7                  Total Farm                          500
# 10      Total Wage and Salary                       701200
# 14            Goods Producing                       100000
# 15              Total Nonfarm                       700700
# ...                       ...                          ...
# 481958       Local Government                      1863700
# 481978             Government                      2684500
# 481998  Total Wage and Salary                     18281800
# 482005        Goods Producing                      2244800
# 482056             Total Farm                       348500
#
#         Regional Labor Force  Regional Employment  Regional Unemployment  \
# 0                     797300               744800                  52500
# 7                     797300               744800                  52500
# 10                    797300               744800                  52500
# 14                    797300               744800                  52500
# 15                    797300               744800                  52500
# ...                      ...                  ...                    ...
# 481958              19409300             18372600                1036700
# 481978              19409300             18372600                1036700
# 481998              19409300             18372600                1036700
# 482005              19409300             18372600                1036700
# 482056              19409300             18372600                1036700
#
#         Regional Unemployment Rate
# 0                              6.6
# 7                              6.6
# 10                             6.6
# 14                             6.6
# 15                             6.6
# ...                            ...
# 481958                         5.3
# 481978                         5.3
# 481998                         5.3
# 482005                         5.3
# 482056                         5.3
#
# [105156 rows x 12 columns]

# %%
Top_10_jobs_df=((top10_filter_emp_df.groupby(top10_filter_emp_df['Industry Title'])['Regional Employment']).mean()).sort_values()

# %%
Top_10_jobs_df.plot.bar()
plt.ylabel("'Regional Employment")
plt.title("Top 10 industries based on employment rate in California")
# Out:
# Text(0.5, 1.0, 'Top 10 industries based on employment rate in California')

# %%
top10_emp_df.tail(20)
# Out:
# Industry Title
# Drinking Places (Alcoholic Beverages)                                                                  123
# Personal & Household Goods Repair                                                                      123
#           Highway, Street, and Bridge Construction                                                     123
# Social Advocacy Organizations                                                                          123
# Indian Tribes                                                                                          123
# Chemical & Allied Products Merchant whol                                                               123
# Lumber & Other Const. Mat Merch whole                                                                  123
# Furniture & Home Furnish Merch whole                                                                   123
# Soap, Cleaning Compound & Toiletry Mfg.                                                                123
# Logging                                                                                                123
# Support Activities for Mining                                                                          123
# Machine Shops & Threaded Product Mfg.                                                                  123
# Other Wood Product Mfg.                                                                                123
# Mining                                                                                                 123
#             Home Furnishings Retailers                                                                 123
#             General Merchandise Retailers - Residual                                                   110
#             Clothing, Clothing Accessories, Shoe, and Jewelry Retailers - Residual                     110
#             Federal Government - Residual                                                              110
#              Trade, Transportation, and Utilities - Residual                                           110
#             Sporting Goods, Hobby, Musical Instrument, Book, and Miscellaneous Retailers - Residual    110
# Name: count, dtype: int64

# %%
job=['Social Advocacy Organizations ','Personal & Household Goods Repair','Drinking Places (Alcoholic Beverages)','Indian Tribes','Chemical & Allied Products Merchant whol','Lumber & Other Const. Mat Merch whole','Furniture & Home Furnish Merch whole','Soap, Cleaning Compound & Toiletry Mfg.','Logging','Support Activities for Mining']
filter_emp_df=employment_df.loc[employment_df['Industry Title'].isin(job)]
filter_emp_df
# Out:
#         Unnamed: 0 Area Type   Area Name  Year    Month       Date  \
# 3766          3766     State  California  2014  January  01/1/2014
# 3768          3768     State  California  2014  January  01/1/2014
# 3770          3770     State  California  2014  January  01/1/2014
# 3773          3773     State  California  2014  January  01/1/2014
# 3774          3774     State  California  2014  January  01/1/2014
# ...            ...       ...         ...   ...      ...        ...
# 481907      481907     State  California  2024    March  03/1/2024
# 481973      481973     State  California  2024    March  03/1/2024
# 481983      481983     State  California  2024    March  03/1/2024
# 481985      481985     State  California  2024    March  03/1/2024
# 482060      482060     State  California  2024    March  03/1/2024
#
#                                  Industry Title  Industry Current Employment  \
# 3766              Support Activities for Mining                        14900
# 3768                                    Logging                         1500
# 3770    Soap, Cleaning Compound & Toiletry Mfg.                        11200
# 3773       Furniture & Home Furnish Merch whole                        19900
# 3774      Lumber & Other Const. Mat Merch whole                        18900
# ...                                         ...                          ...
# 481907                                  Logging                         2100
# 481973                            Indian Tribes                        67900
# 481983        Personal & Household Goods Repair                        10000
# 481985    Drinking Places (Alcoholic Beverages)                        34400
# 482060            Support Activities for Mining                         7800
#
#         Regional Labor Force  Regional Employment  Regional Unemployment  \
# 3766                18496400             16922600                1573700
# 3768                18496400             16922600                1573700
# 3770                18496400             16922600                1573700
# 3773                18496400             16922600                1573700
# 3774                18496400             16922600                1573700
# ...                      ...                  ...                    ...
# 481907              19409300             18372600                1036700
# 481973              19409300             18372600                1036700
# 481983              19409300             18372600                1036700
# 481985              19409300             18372600                1036700
# 482060              19409300             18372600                1036700
#
#         Regional Unemployment Rate
# 3766                           8.5
# 3768                           8.5
# 3770                           8.5
# 3773                           8.5
# 3774                           8.5
# ...                            ...
# 481907                         5.3
# 481973                         5.3
# 481983                         5.3
# 481985                         5.3
# 482060                         5.3
#
# [1107 rows x 12 columns]

# %%
Bottom_10_jobs_df=((filter_emp_df.groupby(filter_emp_df['Industry Title'])['Regional Employment']).mean()).sort_values()

# %%
Bottom_10_jobs_df.plot.bar()
plt.ylabel("'Regional Employment")
plt.title("Bottom 10 industries based on employment rate in California")
# Out:
# Text(0.5, 1.0, 'Bottom 10 industries based on employment rate in California')

# %%
area_emp_df=(employment_df.groupby(['Area Name'])['Regional Unemployment Rate']).sum().sort_values(ascending=False)
top_area_emp_df=area_emp_df.head(10)
top_area_emp_df
# Out:
# Area Name
# California                              204669.4
# Los Angeles-Long Beach-Glendale MD      143510.3
# Los Angeles County                      142043.4
# Imperial County                          70067.2
# El Centro MSA                            70067.2
# Riverside-San Bernardino-Ontario MSA     68959.5
# Bakersfield MSA                          64097.0
# Kern County                              64097.0
# San Diego-Carlsbad MSA                   63786.1
# San Diego County                         63219.6
# Name: Regional Unemployment Rate, dtype: float64

# %%
top_area_emp_df.plot.bar(rot=90)
plt.title("top 10 areas having high unemployment rate")
plt.ylabel("Total unemployment rate")
# Out:
# Text(0, 0.5, 'Total unemployment rate')

# %%
bottom_area_emp_df=area_emp_df.tail(10)
bottom_area_emp_df
# Out:
# Area Name
# San Rafael MD           15602.9
# Marin County            15602.9
# Placer County           15558.9
# Trinity County          14923.8
# Nevada County           14508.0
# Santa Clara County      13472.6
# San Francisco County    13302.4
# San Mateo County        12281.6
# Alpine County           10495.2
# Sierra County           10065.6
# Name: Regional Unemployment Rate, dtype: float64

# %%
bottom_area_emp_df.plot.bar(rot=90)
plt.title("Bottom 10 areas having less unemployment rate")
plt.ylabel("Total unemployment rate")
# Out:
# Text(0, 0.5, 'Total unemployment rate')

# %%
employment_df['Area Name'].unique()

# %%
   import csv

data = ['Alameda County', 'Alpine County', 'Amador County', 'Butte County',
        'Calaveras County', 'Colusa County', 'Contra Costa County',
        'Del Norte County', 'El Dorado County', 'Fresno County',
        'Glenn County', 'Humboldt County', 'Imperial County',
        'Inyo County', 'Kern County', 'Kings County', 'Lake County',
        'Lassen County', 'Los Angeles County', 'Madera County',
        'Marin County', 'Mariposa County', 'Mendocino County',
        'Merced County', 'Modoc County', 'Mono County', 'Monterey County',
        'Napa County', 'Nevada County', 'Orange County', 'Placer County',
        'Plumas County', 'Riverside County', 'Sacramento County',
        'San Benito County', 'San Bernardino County', 'San Diego County',
        'San Francisco County', 'San Joaquin County',
        'San Luis Obispo County', 'San Mateo County',
        'Santa Barbara County', 'Santa Clara County', 'Santa Cruz County',
        'Shasta County', 'Sierra County', 'Siskiyou County',
        'Solano County', 'Sonoma County', 'Stanislaus County',
        'Sutter County', 'Tehama County', 'Trinity County',
        'Tulare County', 'Tuolumne County', 'Ventura County',
        'Yolo County', 'Yuba County', 'Anaheim-Santa Ana-Irvine MD',
        'Bakersfield MSA', 'Chico MSA', 'El Centro MSA', 'Fresno MSA',
        'Hanford-Corcoran MSA', 'Los Angeles-Long Beach-Glendale MD',
        'Madera MSA', 'Merced MSA', 'Modesto MSA', 'Napa MSA',
        'Oakland-Hayward-Berkeley MD', 'Oxnard-Thousand Oaks-Ventura MSA',
        'Redding MSA', 'Riverside-San Bernardino-Ontario MSA',
        'Sacramento--Roseville--Arden-Arcade MSA', 'Salinas MSA',
        'San Diego-Carlsbad MSA',
        'San Francisco-Redwood City-South San Francisco MD',
        'San Jose-Sunnyvale-Santa Clara MSA',
        'San Luis Obispo-Paso Robles-Arroyo Grande MSA', 'San Rafael MD',
        'Santa Cruz-Watsonville MSA', 'Santa Maria-Santa Barbara MSA',
        'Santa Rosa MSA', 'Stockton-Lodi MSA', 'Vallejo-Fairfield MSA',
        'Visalia-Porterville MSA', 'Yuba City MSA', 'California']


csv_file = "./Datasets/places.csv"


with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Place"])
    for place in data:
        writer.writerow([place])

# %%
employment_df.head()
# Out:
#    Unnamed: 0 Area Type       Area Name  Year    Month       Date  \
# 0           0    County  Alameda County  2014  January  01/1/2014
# 1           1    County  Alameda County  2014  January  01/1/2014
# 2           2    County  Alameda County  2014  January  01/1/2014
# 3           3    County  Alameda County  2014  January  01/1/2014
# 4           4    County  Alameda County  2014  January  01/1/2014
#
#                                       Industry Title  \
# 0                                      Manufacturing
# 1                                    Wholesale Trade
# 2          Transportation, Warehousing, and Utili...
# 3                                        Information
# 4            Management of Companies and Enterprises
#
#    Industry Current Employment  Regional Labor Force  Regional Employment  \
# 0                        65300                797300               744800
# 1                        36700                797300               744800
# 2                        24400                797300               744800
# 3                        13900                797300               744800
# 4                        18400                797300               744800
#
#    Regional Unemployment  Regional Unemployment Rate
# 0                  52500                         6.6
# 1                  52500                         6.6
# 2                  52500                         6.6
# 3                  52500                         6.6
# 4                  52500                         6.6

# %%
area_df=(employment_df.groupby(employment_df['Area Name'])['Regional Unemployment']).mean()
area_df=pd.DataFrame(area_df)
area_df
# Out:
#                              Regional Unemployment
# Area Name
# Alameda County                        39342.592593
# Alpine County                            37.886179
# Amador County                           867.317073
# Anaheim-Santa Ana-Irvine MD           71153.658537
# Bakersfield MSA                       36764.227642
# ...                                            ...
# Ventura County                        21981.274900
# Visalia-Porterville MSA               22178.861789
# Yolo County                            6034.259259
# Yuba City MSA                          6556.097561
# Yuba County                            2409.259259
#
# [88 rows x 1 columns]

# %%
coordinates_df = pd.read_csv('./Datasets/coordinates.csv')

# %%
coordinates_df=coordinates_df.rename(columns={'Place':'Area Name'})
coordinates_df
# Out:
#                   Area Name   Latitude   Longitude
# 0            Alameda County  37.601689 -121.719546
# 1             Alpine County  38.594074 -119.881520
# 2             Amador County  38.409242 -120.666004
# 3              Butte County  39.647441 -121.634452
# 4          Calaveras County  38.231085 -120.619990
# ..                      ...        ...         ...
# 83        Stockton-Lodi MSA  37.992179 -121.308409
# 84    Vallejo-Fairfield MSA  38.104086 -122.256637
# 85  Visalia-Porterville MSA  36.330133 -119.296637
# 86            Yuba City MSA  39.140448 -121.616911
# 87               California  36.778261 -119.417932
#
# [88 rows x 3 columns]

# %%
area_emp_df=pd.merge(area_df,coordinates_df,on='Area Name')
area_emp_df
# Out:
#                       Area Name  Regional Unemployment   Latitude   Longitude
# 0                Alameda County           39342.592593  37.601689 -121.719546
# 1                 Alpine County              37.886179  38.594074 -119.881520
# 2                 Amador County             867.317073  38.409242 -120.666004
# 3   Anaheim-Santa Ana-Irvine MD           71153.658537  33.745472 -117.867653
# 4               Bakersfield MSA           36764.227642  35.373292 -119.018713
# ..                          ...                    ...        ...         ...
# 83               Ventura County           21981.274900  34.370488 -119.139064
# 84      Visalia-Porterville MSA           22178.861789  36.330133 -119.296637
# 85                  Yolo County            6034.259259  38.764602 -121.901795
# 86                Yuba City MSA            6556.097561  39.140448 -121.616911
# 87                  Yuba County            2409.259259  39.254703 -121.399900
#
# [88 rows x 4 columns]

# %%
map_plot = area_emp_df.hvplot.points(
    "Longitude",
    "Latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 1000,
    frame_height = 1000,
    size = "Regional Unemployment",
    scale = 0.03,
    color = "Area Name",
    hover_cols=['Area Name	', 'Regional Unemployment'],
    title="Average unemployment by area"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (Area Name,Regional Unemployment)
